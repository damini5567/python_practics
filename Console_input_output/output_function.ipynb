# %% [markdown]
# ## Console input output

# %% [markdown]
# ### output- print()

# %%
num=556
print(num)
# Out:
# 556

# %%
print("Avantika")
# Out:
# Avantika

# %%
print(50)
print(type(50))
# Out:
# 50
# <class 'int'>

# %%
print(16.5)
print(type(16.5))
# Out:
# 16.5
# <class 'float'>

# %%
print(1+2j)
print(type(1+2j))
# Out:
# (1+2j)
# <class 'complex'>

# %%
print(True)
print(type(True))
# Out:
# True
# <class 'bool'>

# %%
print("Avantika")
print(type("Avantika"))
# Out:
# Avantika
# <class 'str'>

# %%
name="rahul"
print(name)
print(type(name))
print(id(name))
# Out:
# rahul
# <class 'str'>
# 2273376244416

# %%
height=5.8
print(height)
print(type(height))
# Out:
# 5.8
# <class 'float'>

# %%
weight=65.7
print(weight)
print(type(weight))
# Out:
# 65.7
# <class 'float'>

# %%
print(name,height,weight)
print("Rahul", 5.8, 65.7)
# Out:
# rahul 5.8 65.7
# Rahul 5.8 65.7

# %%
name="Avantika"
weight=70
print("My name is :",name,"and my weight is:",weight)
print("my weight is -",weight)
# Out:
# My name is : Avantika and my weight is: 70
# my weight is - 70

# %%
print("my height is:",height,"my weight is:",weight)
print(name,height,weight)
# Out:
# my height is: 5.8 my weight is: 70
# Avantika 5.8 70

# %% [markdown]
# ### Memory address and value printing

# %%
num1=10
print(num1)
print(id(num1))

#here now num1 is stored in new memory address not same memory address.
num1=20
print(num1)
print(id(num1))
# Out:
# 10
# 140708372923800
# 20
# 140708372924120

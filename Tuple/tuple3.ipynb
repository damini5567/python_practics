# %% [markdown]
# ## Built in functions in tuple

# %% [markdown]
# ### 1. len( )

# %%
tuple1=(10,20,30)
print(len(tuple1))
# Out:
# 3

# %% [markdown]
# ### 2. max( )

# %%
tuple1=(10,20,30)
print(max(tuple1))
# Out:
# 30

# %% [markdown]
# ### 3.min( )

# %%
tuple1=(10,20,30)
print(min(tuple1))
# Out:
# 10

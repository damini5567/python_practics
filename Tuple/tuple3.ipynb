# %% [markdown]
# ## Built in functions in tuple

# %% [markdown]
# ### 1. len( )

# %%
tuple1=(10,20,30)
print(len(tuple1))
# Out:
# 3

# %% [markdown]
# ### 2. max( )

# %%
tuple1=(10,20,30)
print(max(tuple1))
# Out:
# 30

# %% [markdown]
# ### 3.min( )

# %%
tuple1=(10,20,30)
print(min(tuple1))
# Out:
# 10

# %% [markdown]
# ### 4.sum( )

# %%
tuple1=(10,20,30)
print(sum(tuple1))
# Out:
# 60

# %% [markdown]
# ### 5.any( )

# %%
tuple1=(0,0,0,1)
print(any(tuple1))
# Out:
# True

# %%
tuple2=(0,0,0,0)
print(any(tuple2))
# Out:
# False

# %% [markdown]
# ### 6. all( )

# %%
tuple1=(10,20,30,40,"Avantika",10.1)
print(all(tuple1))
# Out:
# True

# %%
tuple1=(10,20,30,40,"Avantika",0)
print(all(tuple1))
# Out:
# False

# %% [markdown]
# ### 7.sorted( )

# %%
tuple1=(50,40,10,20,30)
print(tuple(sorted(tuple1)))
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# ### 8. reversed( )

# %%
tuple1=(10,20,30,40,50)
result=reversed(tuple1)
print(result)

# %%
print(tuple(result))
# Out:
# (50, 40, 30, 20, 10)

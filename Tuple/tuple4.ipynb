# %% [markdown]
# ## Tuple methods

# %% [markdown]
# ### 1. index( )

# %%
tuple1=(10,20,30,40,50)
print(tuple1.index(30))
print(tuple1.index(50))
# print(tuple1.index(100)) ->ValueError
# Out:
# 2
# 4

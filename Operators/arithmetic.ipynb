# %% [markdown]
# ## 1) Arithmetic operator

# %%
p=12
q=4
result=p+q
print(result)
# Out:
# 16

# %%
p=12
q=4
result=p-q
print(result)
# Out:
# 8

# %%
p=12
q=4
result=p*q
print(result)
# Out:
# 48

# %%
p=12
q=4
result=p/q
print(result)
# Out:
# 3.0

# %%
p=12
q=4
result=p//q
print(result)
# Out:
# 3

# %%
p=12
q=4
result=p%q
print(result)
# Out:
# 0

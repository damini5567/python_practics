# %% [markdown]
# ### Python Basic Data Types

# %% [markdown]
# ##### Integer

# %%
decimal_num=10
print(decimal_num)
# Out:
# 10

# %%
binary_num=0b1010
print(binary_num)
# Out:
# 10

# %%
octal_num=10
print(octal_num)
# Out:
# 10

# %%
hexadecimal_num=0xA
print(hexadecimal_num)
# Out:
# 10

# %% [markdown]
# #### float

# %% [markdown]
# ##### 1)decimal notation

# %%
pi=3.14
print(pi)
print(type(pi))
# Out:
# 3.14
# <class 'float'>

# %% [markdown]
# ##### 2) exponential Notation

# %%
var1=6.02e23
print(var1)
print(type(var1))
# Out:
# 6.02e+23
# <class 'float'>

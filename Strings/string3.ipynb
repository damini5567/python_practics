# %% [markdown]
# #### BUILT IN FUNCTIONS IN STRING

# %% [markdown]
# ### 1) len()

# %%
str1="Artificial Intelligence"
print(len(str1))
# Out:
# 23

# %% [markdown]
# ### 2) min()

# %%
str2="hello"
print(min(str2))
# Out:
# e

# %% [markdown]
# ### 3) max()

# %%
str2="hello"
print(max(str2))
# Out:
# o

# %% [markdown]
# ### ord()

# %%
str1="welcome"
ord("w")
# Out:
# 119

# %% [markdown]
# ## Basic List Operations

# %% [markdown]
# ### 1) Mutability

# %%
List1=[10,20,30,40,50]
print(List1)
print(type(List1))
List1[0]=0
print(List1)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# [0, 20, 30, 40, 50]

# %% [markdown]
# ### string is immutable

# %%
str1="Hello"
print(str1)
print(type(str1))
# Out:
# Hello
# <class 'str'>

# %%
str1[0]="h"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 str1[0]="h"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### 2.Concatenation and 3.Merging-  + operator

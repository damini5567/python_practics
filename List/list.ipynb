# %% [markdown]
# ## CONTAINER DATA TYPES

# %% [markdown]
# ## 1) List

# %% [markdown]
# ### Define list

# %%
list1= ["Avantika",101,25,"BCA"]
print(list1)
# Out:
# ['Avantika', 101, 25, 'BCA']

# %% [markdown]
# #### Homogenous list

# %%
list2=[51,52,53,54,55]
print(list2)
# Out:
# [51, 52, 53, 54, 55]

# %% [markdown]
# #### Hetrogenous list

# %%
list3=["Avantika",25,"BE"]
print(list3)
# Out:
# ['Avantika', 25, 'BE']

# %% [markdown]
# #### Duplicate elements are allowed in list

# %%
list4=[10,20,30,10,20,30]
print(list4)
# Out:
# [10, 20, 30, 10, 20, 30]

# %% [markdown]
# #### Repitation of elements using * operator

# %%
list5=[10,20,30,40,50]*2
print(list5)
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %% [markdown]
# #### Accessing list elements

# %%
list6=[10,20,30,40,50]
print(list6)
# Out:
# [10, 20, 30, 40, 50]

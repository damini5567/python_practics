# %% [markdown]
# ### 2) if_else block

# %%
age=25
if (age>=18):
    print("You are eligible for voting")
else:
    print("You are not eligiblr for voting")    
print("program executed")
# Out:
# You are eligible for voting
# program executed

# %%
age=15
if (age>=18):
    print("You are eligible for voting")
else:
    print("You are not eligiblr for voting")    
print("program executed")
# Out:
# You are not eligiblr for voting
# program executed

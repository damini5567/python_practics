# %% [markdown]
# ## Set Built-in functions

# %% [markdown]
# ### 1.len( )

# %%
set1={10,20,30,40,50}
print(len(set1))
# Out:
# 5

# %% [markdown]
# ### 2. max()

# %%
set1={10,20,30,40,50}
print(max(set1))
# Out:
# 50
